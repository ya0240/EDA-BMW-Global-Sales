# %% [markdown]
# # BMW Global Sales EDA
#
# * In this project, I engineered a BMW Global Sales dashboard to visualize historical performance. Conducted statistical analysis to uncover latent sales patterns, providing stakeholders with the insights necessary to optimize strategic business decisions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
car = pd.read_csv("../dataset/bmw_global_sales_2018_2025.csv")

# %%
car.sample(10)
# Out:
#       Year  Month       Region     Model  Units_Sold  Avg_Price_EUR  \
# 2976  2025     10       Europe  3 Series        7480          48398
# 1171  2021      1          USA        X5        2936          68973
# 859   2020      3  RestOfWorld        X5       13861          68772
# 1918  2022     12  RestOfWorld        iX       14038          73614
# 1528  2021     12  RestOfWorld  3 Series       10135          47462
# 1857  2022     11       Europe  5 Series        8365          61096
# 2510  2024      7        China        iX       12185          73792
# 388   2019      1       Europe        X7        3520          91562
# 2729  2025      2        China  5 Series        5073          62052
# 2811  2025      4  RestOfWorld        X5        4043          68179
#
#       Revenue_EUR  BEV_Share  Premium_Share  GDP_Growth  Fuel_Price_Index
# 2976    362017040      0.202          19.10        4.06              1.38
# 1171    202504728      0.107          18.71        2.47              1.16
# 859     953248692      0.074           6.54        2.49              1.10
# 1918   1033393332      0.111           5.26        3.70              1.26
# 1528    481027370      0.100           6.72        2.20              1.23
# 1857    511068040      0.119          14.38        2.28              1.18
# 2510    899155520      0.193          14.77        1.79              1.29
# 388     322298240      0.056          19.31        2.44              1.06
# 2729    314789796      0.187          20.36        5.25              1.34
# 2811    275647697      0.186           5.67        3.39              1.31

# %%
print(f"There are {car.shape[0]} Rows and {car.shape[1]} Columns.")
# Out:
# There are 3072 Rows and 11 Columns.

# %% [markdown]
# ## Checking For Any Missing & Duplicate Values

# %%
car.isnull().sum()
# Out:
# Year                0
# Month               0
# Region              0
# Model               0
# Units_Sold          0
# Avg_Price_EUR       0
# Revenue_EUR         0
# BEV_Share           0
# Premium_Share       0
# GDP_Growth          0
# Fuel_Price_Index    0
# dtype: int64

# %%
car.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking The Unique Values Of Categorical Columns

# %%
def categorical_column():
    object_columns = car.select_dtypes(include=['object']).columns
    for col in object_columns:
        unique_vals = car[col].unique()
        print(f"Unique Values Of Categorical Column: {unique_vals}")

# %%
categorical_column()
# Out:
# Unique Values Of Categorical Column: ['Europe' 'China' 'USA' 'RestOfWorld']
# Unique Values Of Categorical Column: ['3 Series' '5 Series' 'X3' 'X5' 'X7' 'i4' 'iX' 'MINI']

# %% [markdown]
# ## Overview Of Data

# %%
car.describe()
# Out:
#               Year        Month    Units_Sold  Avg_Price_EUR   Revenue_EUR  \
# count  3072.000000  3072.000000   3072.000000    3072.000000  3.072000e+03
# mean   2021.500000     6.500000   7980.288086   63854.561523  5.113995e+08
# std       2.291661     3.452615   3174.917444   14655.891299  2.431185e+08
# min    2018.000000     1.000000   2379.000000   40011.000000  1.045314e+08
# 25%    2019.750000     3.750000   5225.500000   54500.250000  3.125504e+08
# 50%    2021.500000     6.500000   7985.500000   63493.000000  4.808690e+08
# 75%    2023.250000     9.250000  10528.250000   71489.500000  6.709141e+08
# max    2025.000000    12.000000  15914.000000   93994.000000  1.433482e+09
#
#          BEV_Share  Premium_Share   GDP_Growth  Fuel_Price_Index
# count  3072.000000    3072.000000  3072.000000       3072.000000
# mean      0.107572      14.660234     3.057526          1.176224
# std       0.058099       5.334604     1.018103          0.118123
# min      -0.015000       5.090000     0.100000          0.920000
# 25%       0.057000      12.275000     2.370000          1.080000
# 50%       0.108000      16.260000     3.060000          1.180000
# 75%       0.157250      18.932500     3.852500          1.270000
# max       0.223000      20.970000     5.820000          1.410000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3072 entries, 0 to 3071
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              3072 non-null   int64
#  1   Month             3072 non-null   int64
#  2   Region            3072 non-null   object
#  3   Model             3072 non-null   object
#  4   Units_Sold        3072 non-null   int64
#  5   Avg_Price_EUR     3072 non-null   int64
#  6   Revenue_EUR       3072 non-null   int64
#  7   BEV_Share         3072 non-null   float64
#  8   Premium_Share     3072 non-null   float64
#  9   GDP_Growth        3072 non-null   float64
#  10  Fuel_Price_Index  3072 non-null   float64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 264.1+ KB

# %%
plt.figure(figsize=(16,8))
sns.heatmap(car.corr(), annot=True,cmap='viridis')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Univariate Analysis On Numerical Columns

# %%
sns.displot(car['Revenue_EUR'],kde=True)

# %% [markdown]
# ## Log-Normal Distribution

# %%
log_price = np.log1p(car['Revenue_EUR'])

# %%
sns.histplot(data = sorted(log_price), kde=True)
plt.title("Log-Transformed Data")
plt.show()

# %% [markdown]
# ## Box Plot To Check For Outliers On Every Numerical Columns

# %%
a = sorted(car['Revenue_EUR'])
sns.boxplot(a)
# Out:
# <AxesSubplot: >

# %%
# Calculate IQR Of Revenue Column Of BMW
Q1 = car['Revenue_EUR'].quantile(0.25)
Q3 = car['Revenue_EUR'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

#Calculate Upper Bound & Lower Bound
Upper_Bound = Q1 - (1.5*IQR)
Lower_Bound = Q3 + (1.5*IQR)

print(f"IQR: {IQR}")
print(f"Maximum Value Of Revenue Column: {Upper_Bound}")
print(f"Minimum Value Of Revenue Column: {Lower_Bound}")
# Out:
# IQR: 358363776.25
# Maximum Value Of Revenue Column: -224995312.125
# Minimum Value Of Revenue Column: 1208459792.875

# %%
df1 = car[car['Revenue_EUR'] > 1208459792.875]

# %%
df1
# Out:
#       Year  Month       Region Model  Units_Sold  Avg_Price_EUR  Revenue_EUR  \
# 452   2019      3       Europe    X7       13295          91058   1210616110
# 836   2020      3       Europe    X7       13645          91053   1242418185
# 1124  2020     12       Europe    X7       13404          93509   1253394636
# 1316  2021      6       Europe    X7       13799          90011   1242061789
# 1428  2021      9          USA    X7       14215          93386   1327481990
# 1516  2021     12        China    X7       14353          91024   1306467472
# 1524  2021     12          USA    X7       13944          90129   1256758776
# 1700  2022      6       Europe    X7       14100          91334   1287809400
# 1820  2022      9  RestOfWorld    X7       13417          91272   1224596424
# 1892  2022     12       Europe    X7       13906          90555   1259257830
# 2108  2023      6  RestOfWorld    X7       13568          92488   1254877184
# 2404  2024      4       Europe    X7       13423          92633   1243412759
# 2436  2024      5       Europe    X7       13376          91495   1223837120
# 2444  2024      5        China    X7       13421          93816   1259104536
# 2500  2024      7       Europe    X7       13218          92869   1227542442
# 2572  2024      9        China    X7       15061          90157   1357854577
# 2612  2024     10          USA    X7       13352          91830   1226114160
# 2668  2024     12        China    X7       14810          92812   1374545720
# 2764  2025      3        China    X7       15448          92794   1433481712
# 2852  2025      6       Europe    X7       13947          90006   1255313682
# 2876  2025      6  RestOfWorld    X7       14786          92278   1364422508
# 2956  2025      9        China    X7       14802          90096   1333600992
# 3044  2025     12       Europe    X7       14561          93587   1362720307
#
#       BEV_Share  Premium_Share  GDP_Growth  Fuel_Price_Index
# 452       0.046          16.50        4.40              1.00
# 836       0.059          15.31        4.48              1.09
# 1124      0.074          14.13        2.66              1.11
# 1316      0.104          17.30        1.33              1.15
# 1428      0.092          18.52        3.18              1.11
# 1516      0.095          16.14        3.31              1.12
# 1524      0.078          14.85        2.49              1.15
# 1700      0.112          20.37        3.07              1.12
# 1820      0.118           6.95        3.43              1.18
# 1892      0.117          14.24        1.31              1.22
# 2108      0.151           5.82        1.42              1.27
# 2404      0.187          16.13        3.25              1.23
# 2436      0.199          20.51        4.00              1.25
# 2444      0.166          19.85        2.26              1.26
# 2500      0.157          14.70        3.90              1.27
# 2572      0.160          19.75        2.40              1.31
# 2612      0.156          20.60        2.94              1.28
# 2668      0.173          19.13        1.86              1.27
# 2764      0.205          18.76        4.46              1.34
# 2852      0.197          18.81        3.25              1.35
# 2876      0.198           5.31        3.12              1.37
# 2956      0.204          20.90        5.43              1.33
# 3044      0.197          20.15        2.50              1.35

# %%
df1['Region'].value_counts()
# Out:
# Europe         11
# China           6
# USA             3
# RestOfWorld     3
# Name: Region, dtype: int64

# %% [markdown]
# ### Conclusion
# * The raw data was slightly skewed, but the log transformation reveals a clear underlying Normal Distribution, proving the data is Log-Normal.
#
# * The data appears to be accurate. Surprisingly, the BMW X7 has secured the top-selling model in Europe compared to other regions.
#
# * A majority of consumers are transitioning toward the BMW X7, this shift toward SUVs suggests that buyers are prioritizing comfort and utility over raw speed and traditional styling.

# %% [markdown]
# ## 2. What is the total sales volume (units sold) by region?

# %%
sns.barplot(data=car,x = car['Region'],y=car['Units_Sold'])
# Out:
# <AxesSubplot: xlabel='Region', ylabel='Units_Sold'>

# %% [markdown]
# ## Univariate Analysis Of Categorical Columns

# %%
car['Model'].value_counts().plot(kind='pie',autopct = '%0.1f%%' )
# Out:
# <AxesSubplot: ylabel='Model'>

# %%
car['Region'].value_counts().plot(kind='pie',autopct = '%0.1f%%' )
# Out:
# <AxesSubplot: ylabel='Region'>

# %%
pd.crosstab(car['Model'],car['Region'],normalize='columns')*100
# Out:
# Region    China  Europe  RestOfWorld   USA
# Model
# 3 Series   12.5    12.5         12.5  12.5
# 5 Series   12.5    12.5         12.5  12.5
# MINI       12.5    12.5         12.5  12.5
# X3         12.5    12.5         12.5  12.5
# X5         12.5    12.5         12.5  12.5
# X7         12.5    12.5         12.5  12.5
# i4         12.5    12.5         12.5  12.5
# iX         12.5    12.5         12.5  12.5

# %% [markdown]
# ### Conclusion
# * BMW maintains a balanced sales distribution for all models across every region.
# * BMW models maintains a balanced sales distribution across all regions.

# %% [markdown]
# ## Bivariate & Multivariate Analysis

# %%
sns.relplot(data=car,x=car['BEV_Share'],y= car['Fuel_Price_Index'],hue='Region')
plt.show()

# %% [markdown]
# ### Conclusion
# * It indicates that there's postitive correlation between fuel price index and bev (Battery Electric Value) share.

# %%
plt.figure(figsize=(16,8))
sns.barplot(data = car,x = car['Year'],y = car['Revenue_EUR'],hue= "Model")
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Revenue_EUR'>

# %%
plt.figure(figsize=(16,8))
sns.barplot(data = car,x = car['Month'],y = car['Revenue_EUR'],hue= "Model" )
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Revenue_EUR'>

# %%
sns.lineplot(data = car, x = car['Year'],y = car['Units_Sold'])
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Units_Sold'>

# %%
sns.lineplot(data = car, x = car['Month'], y = car['Units_Sold'],color= 'Red')
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Units_Sold'>
